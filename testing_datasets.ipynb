# %%
import cv2
from  keras.models import load_model
from PIL import Image
import numpy as np
import os
import time

# %%
model = load_model("D:\College\Capstone Project 2\data\Trained_models\Big_Brain_tumor_model_1.h5")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
def plot_image(path):
    img = mpimg.imread(path)
    imgplot = plt.imshow(img)
    plt.show()

# %% [markdown]
# # Checking accuracy on other datasets on which this model is not trained but its result is known through verified sources

# %% [markdown]
# ## SET 1

# %% [markdown]
# > Checking for no tumor

# %%
path = r"D:\College\Capstone Project 2\data\brain_tumor_dataset_testing\set_1\no"

incorrect_no_tumor = 0   
for x in os.listdir(path):
    try:
        path = path + "\\" + x 
        image = Image.open(path)

        image = image.resize((224,224))
        image = image.convert('RGB')
        image.save(path)

        image = cv2.imread(path)


        img = np.array(image) / 255.0
        img = np.expand_dims(img, axis = 0)

        result = model.predict(img)
         
        if result.squeeze() > 0.5:
            print(f"Incorrect result on {x}\nExpected: no-tumor\nResult: Tumor")
            incorrect_no_tumor += 1
            plot_image(path)
            
        path = r"D:\College\Capstone Project 2\data\brain_tumor_dataset_testing\set_1\no"
    except Exception as e:
        print(f"{e}  in  {x}")
        plot_image(path)
        path = r"D:\College\Capstone Project 2\data\brain_tumor_dataset_testing\set_1\no"

print(f"Total incorrect: {incorrect_no_tumor} out of {len(os.listdir(path))} images")
# Out:
# Incorrect result on no.60.jpg
# Expected: no-tumor
# Result: Tumor
# Incorrect result on no.82.jpg
# Expected: no-tumor
# Result: Tumor
# Total incorrect: 2 out of 97 images

# %% [markdown]
# > Checking accuracy for images with brain tumor.

# %%
path = r"D:\College\Capstone Project 2\data\brain_tumor_dataset_testing\set_1\yes"
# path = r"C:\Users\Shree\Downloads\t11.JPG"
incorrect_tumor = 0   
for x in os.listdir(path):
    try:
        path = path + "\\" + x 
        image = Image.open(path)

        image = image.resize((224,224))
        image = image.convert('RGB')
        image.save(path)

        image = cv2.imread(path)


        img = np.array(image)
        img = np.expand_dims(img, axis = 0)

        result = model.predict(img)
         
        if result.squeeze() <= 0.5:
            print(f"Incorrect result on {x}\nExpected: Tumor\nResult: No-tumor")
            incorrect_tumor += 1
            plot_image(path)
            
        path = r"D:\College\Capstone Project 2\data\brain_tumor_dataset_testing\set_1\yes"
    except Exception as e:
        print(f"{e}  in  {x}")
        path = r"D:\College\Capstone Project 2\data\brain_tumor_dataset_testing\set_1\yes"
        plot_image(path)

print(f"Total incorrect: {incorrect_tumor} in {len(os.listdir(path))} images")
# Out:
# Incorrect result on yes.55.jpg
# Expected: Tumor
# Result: No-tumor
# Total incorrect: 1 in 154 images

# %% [markdown]
# Result

# %%
incorrect_ans = {"No-Tumor": incorrect_no_tumor,
                "Tumor": incorrect_tumor,}
# 4 incorect in 253 (97 inc + 156 corr) images

accuracy = 100 * (1 - (incorrect_no_tumor+incorrect_tumor)//(154 + 97))
print(incorrect_ans)
print(f"Accuracy of model based on this dataset is around {accuracy}%")
# Out:
# {'No-Tumor': 2, 'Tumor': 1}
# Accuracy of model based on this dataset is around 100%

# %% [markdown]
# ## Set 2

# %% [markdown]
# with tumor

# %%
path = r"D:\College\Capstone Project 2\data\brain_tumor_dataset_testing\set_2\yes"
# path = r"C:\Users\Shree\Downloads\t11.JPG"
incorrect_tumor = 0   
for x in os.listdir(path):
    try:
        path = path + "\\" + x 
        image = Image.open(path)

        image = image.resize((224,224))
        image = image.convert('RGB')
        image.save(path)

        image = cv2.imread(path)


        img = np.array(image)
        img = np.expand_dims(img, axis = 0)

        result = model.predict(img)
         
        if result.squeeze() <= 0.5:
            print(f"Incorrect result on {x}\nExpected: Tumor\nResult: No-tumor")
            incorrect_tumor += 1
            plot_image(path)
            
        path = r"D:\College\Capstone Project 2\data\brain_tumor_dataset_testing\set_2\yes"
    except Exception as e:
        print(f"{e}  in  {x}")
        path = r"D:\College\Capstone Project 2\data\brain_tumor_dataset_testing\set_2\yes"
        plot_image(path)

print(f"Total incorrect: {incorrect_tumor} in {len(os.listdir(path))} images")
# Out:
# Incorrect result on y704.jpg
# Expected: Tumor
# Result: No-tumor
# Incorrect result on y719.jpg
# Expected: Tumor
# Result: No-tumor
# Total incorrect: 2 in 100 images

# %%
path = r"D:\College\Capstone Project 2\data\brain_tumor_dataset_testing\set_2\yes_2"
# path = r"C:\Users\Shree\Downloads\t11.JPG"
incorrect_tumor = 0   
for x in os.listdir(path):
    try:
        path = path + "\\" + x 
        image = Image.open(path)

        image = image.resize((224,224))
        image = image.convert('RGB')
        image.save(path)

        image = cv2.imread(path)


        img = np.array(image)
        img = np.expand_dims(img, axis = 0)

        result = model.predict(img)
         
        if result.squeeze() <= 0.5:
            print(f"Incorrect result on {x}\nExpected: Tumor\nResult: No-tumor")
            incorrect_tumor += 1
            plot_image(path)
            
        path = r"D:\College\Capstone Project 2\data\brain_tumor_dataset_testing\set_2\yes_2"
    except Exception as e:
        print(f"{e}  in  {x}")
        path = r"D:\College\Capstone Project 2\data\brain_tumor_dataset_testing\set_2\yes_2"
        plot_image(path)

print(f"Total incorrect: {incorrect_tumor} in {len(os.listdir(path))} images")
# Out:
# Incorrect result on y20.jpg
# Expected: Tumor
# Result: No-tumor
# Incorrect result on y339.jpg
# Expected: Tumor
# Result: No-tumor
# Incorrect result on y454.jpg
# Expected: Tumor
# Result: No-tumor
# Incorrect result on y470.jpg
# Expected: Tumor
# Result: No-tumor
# Incorrect result on y493.jpg
# Expected: Tumor
# Result: No-tumor
# Incorrect result on y69.jpg
# Expected: Tumor
# Result: No-tumor
# Total incorrect: 6 in 495 images

# %% [markdown]
# no tumor

# %%
path = r"D:\College\Capstone Project 2\data\brain_tumor_dataset_testing\set_2\no"

incorrect_no_tumor = 0   
for x in os.listdir(path):
    try:
        path = path + "\\" + x 
        image = Image.open(path)

        image = image.resize((224,224))
        image = image.convert('RGB')
        image.save(path)

        image = cv2.imread(path)


        img = np.array(image)
        img = np.expand_dims(img, axis = 0)

        result = model.predict(img)
         
        if result.squeeze() > 0.5:
            print(f"Incorrect result on {x}\nExpected: no-tumor\nResult: Tumor")
            incorrect_no_tumor += 1
            plot_image(path)
            
        path = r"D:\College\Capstone Project 2\data\brain_tumor_dataset_testing\set_2\no"
    except Exception as e:
        print(f"{e}  in  {x}")
        path = r"D:\College\Capstone Project 2\data\brain_tumor_dataset_testing\set_2\no"
        plot_image(path)

print(f"Total incorrect: {incorrect_no_tumor} in {len(os.listdir(path))} images")
# Out:
# Incorrect result on image(1).jpg
# Expected: no-tumor
# Result: Tumor
# Incorrect result on image(34).jpg
# Expected: no-tumor
# Result: Tumor
# Incorrect result on image(35).jpg
# Expected: no-tumor
# Result: Tumor
# Incorrect result on image(50).jpg
# Expected: no-tumor
# Result: Tumor
# Incorrect result on image(77).jpg
# Expected: no-tumor
# Result: Tumor
# Incorrect result on image(87).jpg
# Expected: no-tumor
# Result: Tumor
# Incorrect result on image(90).jpg
# Expected: no-tumor
# Result: Tumor
# Incorrect result on image(92).jpg
# Expected: no-tumor
# Result: Tumor
# Total incorrect: 8 in 93 images

# %%
accuracy = 100 - (((2 + 9 + 10) / (100 + 498 + 96)) * 100 )
print(f"Accuracy of model based on this dataset is around {accuracy}%")
# Out:
# Accuracy of model based on this dataset is around 96.97406340057637%
